# %%
import pandas as pd
import xlrd

# %%
#Reading .xlsx file

df = pd.read_excel("C:\\Users\JANHVI TIWARI\Dropbox\My PC (Janhvi)\Downloads\Financial Sample.xlsx", "Sheet1")
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
#Reading .csv file

df = pd.read_csv("C:\\Users\JANHVI TIWARI\Dropbox\My PC (Janhvi)\Downloads\Financial Sample.csv")
df
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
#Creating data frame from a Python Dictionary

empdata = {"segment" : ["Government", "Government", "Midmarket", "Midmarket", "Midmarket"],
          "country" : ["Canada", "Germany", "France", "Germany", "Mexico"],
          "product" : ["Carretera", "Carretera", "Carretera", "Carretera", "Carretera"]
          }

# %%
df = pd.DataFrame(empdata)
df
# Out:
#       segment  country    product
# 0  Government   Canada  Carretera
# 1  Government  Germany  Carretera
# 2   Midmarket   France  Carretera
# 3   Midmarket  Germany  Carretera
# 4   Midmarket   Mexico  Carretera

# %%
empdata = [('Goverment', 'Canada', 'Carretera'),
          ('Government', 'Germany', 'Carretera'),
          ('Midmarket', 'France', 'Carretera'),
          ('Midmarket', 'Germany', 'Carretera'),
          ('Midmarket', 'Mexico', 'Carretera')]

# %%
#Creating Data Frame from python list of tuples

df = pd.DataFrame(empdata, columns=["country", "segment", "product"])
df
# Out:
#       country  segment    product
# 0   Goverment   Canada  Carretera
# 1  Government  Germany  Carretera
# 2   Midmarket   France  Carretera
# 3   Midmarket  Germany  Carretera
# 4   Midmarket   Mexico  Carretera

# %%
#Operations of Data Frames
df = pd.read_csv("C:\\Users\JANHVI TIWARI\Dropbox\My PC (Janhvi)\Downloads\Financial Sample.csv")

# %%
#Knowing number of rows and columns

df.shape
# Out:
# (700, 16)

# %%
r, c = df.shape
print(r)
# Out:
# 700

# %%
#Retrieving Rows from Data Frame
df.head()  #for first 5 rows
# Out:
#       Segment  Country     Product   Discount Band   Units Sold   \
# 0  Government   Canada   Carretera            None    $1,618.50
# 1  Government  Germany   Carretera            None    $1,321.00
# 2   Midmarket   France   Carretera            None    $2,178.00
# 3   Midmarket  Germany   Carretera            None      $888.00
# 4   Midmarket   Mexico   Carretera            None    $2,470.00
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 0                $3.00       $20.00    $32,370.00        $-      $32,370.00
# 1                $3.00       $20.00    $26,420.00        $-      $26,420.00
# 2                $3.00       $15.00    $32,670.00        $-      $32,670.00
# 3                $3.00       $15.00    $13,320.00        $-      $13,320.00
# 4                $3.00       $15.00    $37,050.00        $-      $37,050.00
#
#           COGS        Profit       Date  Month Number  Month Name   Year
# ...

# %%
df.tail()  #for last 5 rows
# Out:
#               Segment                   Country    Product   Discount Band   \
# 695    Small Business                    France   Amarilla            High
# 696    Small Business                    Mexico   Amarilla            High
# 697        Government                    Mexico    Montana            High
# 698        Government                    Canada      Paseo            High
# 699  Channel Partners  United States of America        VTT            High
#
#      Units Sold   Manufacturing Price   Sale Price    Gross Sales   \
# 695   $2,475.00               $260.00      $300.00    $742,500.00
# 696     $546.00               $260.00      $300.00    $163,800.00
# 697   $1,368.00                 $5.00        $7.00      $9,576.00
# 698     $723.00                $10.00        $7.00      $5,061.00
# 699   $1,806.00               $250.00       $12.00     $21,672.00
#
#         Discounts          Sales           COGS        Profit        Date  \
# ...

# %%
df.head(2) #only 2 rows
# Out:
#       Segment  Country     Product   Discount Band   Units Sold   \
# 0  Government   Canada   Carretera            None    $1,618.50
# 1  Government  Germany   Carretera            None    $1,321.00
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 0                $3.00       $20.00    $32,370.00        $-      $32,370.00
# 1                $3.00       $20.00    $26,420.00        $-      $26,420.00
#
#           COGS        Profit       Date  Month Number  Month Name   Year
# 0   $16,185.00    $16,185.00   1/1/2014             1     January   2014
# 1   $13,210.00    $13,210.00   1/1/2014             1     January   2014

# %%
df.tail(2) #only 2 tail
# Out:
#               Segment                   Country  Product   Discount Band   \
# 698        Government                    Canada    Paseo            High
# 699  Channel Partners  United States of America      VTT            High
#
#      Units Sold   Manufacturing Price   Sale Price   Gross Sales   \
# 698     $723.00                $10.00        $7.00     $5,061.00
# 699   $1,806.00               $250.00       $12.00    $21,672.00
#
#       Discounts         Sales         COGS        Profit       Date  \
# 698     $759.15     $4,301.85    $3,615.00       $686.85   4/1/2014
# 699   $3,250.80    $18,421.20    $5,418.00    $13,003.20   5/1/2014
#
#      Month Number  Month Name   Year
# 698             4       April   2014
# 699             5         May   2014

# %%
#Retrieving a Range of Rows
df[2:5]
# Out:
#      Segment  Country     Product   Discount Band   Units Sold   \
# 2  Midmarket   France   Carretera            None    $2,178.00
# 3  Midmarket  Germany   Carretera            None      $888.00
# 4  Midmarket   Mexico   Carretera            None    $2,470.00
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 2                $3.00       $15.00    $32,670.00        $-      $32,670.00
# 3                $3.00       $15.00    $13,320.00        $-      $13,320.00
# 4                $3.00       $15.00    $37,050.00        $-      $37,050.00
#
#           COGS        Profit       Date  Month Number  Month Name   Year
# 2   $21,780.00    $10,890.00   6/1/2014             6        June   2014
# 3    $8,880.00     $4,440.00   6/1/2014             6        June   2014
# 4   $24,700.00    $12,350.00   6/1/2014             6        June   2014

# %%
df[0::2]
# Out:
#             Segment                   Country     Product   Discount Band   \
# 0        Government                    Canada   Carretera            None
# 2         Midmarket                    France   Carretera            None
# 4         Midmarket                    Mexico   Carretera            None
# 6         Midmarket                   Germany     Montana            None
# 8        Government                    France     Montana            None
# ..              ...                       ...          ...             ...
# 690      Government  United States of America         VTT            High
# 692      Enterprise                    Canada         VTT            High
# 694      Government                    France         VTT            High
# 696  Small Business                    Mexico    Amarilla            High
# 698      Government                    Canada       Paseo            High
#
#      Units Sold   Manufacturing Price   Sale Price    Gross Sales   \
# ...

# %%
df[5:0:-1] #row in reverse order
# Out:
#       Segment  Country     Product   Discount Band   Units Sold   \
# 5  Government  Germany   Carretera            None    $1,513.00
# 4   Midmarket   Mexico   Carretera            None    $2,470.00
# 3   Midmarket  Germany   Carretera            None      $888.00
# 2   Midmarket   France   Carretera            None    $2,178.00
# 1  Government  Germany   Carretera            None    $1,321.00
#
#    Manufacturing Price   Sale Price    Gross Sales   Discounts   \
# 5                $3.00      $350.00    $529,550.00        $-
# 4                $3.00       $15.00     $37,050.00        $-
# 3                $3.00       $15.00     $13,320.00        $-
# 2                $3.00       $15.00     $32,670.00        $-
# 1                $3.00       $20.00     $26,420.00        $-
#
#           Sales           COGS         Profit        Date  Month Number  \
# 5   $529,550.00    $393,380.00    $136,170.00   12/1/2014            12
# ...

# %%
#To Retrieve Column Names
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', ' Units Sold ',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
df.Segment
# Out:
# 0            Government
# 1            Government
# 2             Midmarket
# 3             Midmarket
# 4             Midmarket
#              ...
# 695      Small Business
# 696      Small Business
# 697          Government
# 698          Government
# 699    Channel Partners
# Name: Segment, Length: 700, dtype: object

# %%
df['Segment']
# Out:
# 0            Government
# 1            Government
# 2             Midmarket
# 3             Midmarket
# 4             Midmarket
#              ...
# 695      Small Business
# 696      Small Business
# 697          Government
# 698          Government
# 699    Channel Partners
# Name: Segment, Length: 700, dtype: object

# %%
#Retrieving Data from Multiple Columns
df[['Segment', 'Country']]
# Out:
#               Segment                   Country
# 0          Government                    Canada
# 1          Government                   Germany
# 2           Midmarket                    France
# 3           Midmarket                   Germany
# 4           Midmarket                    Mexico
# ..                ...                       ...
# 695    Small Business                    France
# 696    Small Business                    Mexico
# 697        Government                    Mexico
# 698        Government                    Canada
# 699  Channel Partners  United States of America
#
# [700 rows x 2 columns]

# %%
#Finding max and min values
df['Month Number'].max()
# Out:
# 12

# %%
df['Month Number'].min()
# Out:
# 1

# %%
#Displaying Statistical Information
df.describe()
# Out:
#        Month Number         Year
# count    700.000000   700.000000
# mean       7.900000  2013.750000
# std        3.377321     0.433322
# min        1.000000  2013.000000
# 25%        5.750000  2013.750000
# 50%        9.000000  2014.000000
# 75%       10.250000  2014.000000
# max       12.000000  2014.000000

# %%
#Performing queries on data
df[df['Month Number']>5]
# Out:
#               Segment  Country     Product   Discount Band   Units Sold   \
# 2           Midmarket   France   Carretera            None    $2,178.00
# 3           Midmarket  Germany   Carretera            None      $888.00
# 4           Midmarket   Mexico   Carretera            None    $2,470.00
# 5          Government  Germany   Carretera            None    $1,513.00
# 7    Channel Partners   Canada     Montana            None    $2,518.00
# ..                ...      ...          ...             ...          ...
# 691         Midmarket  Germany         VTT            High    $1,175.00
# 692        Enterprise   Canada         VTT            High    $2,954.00
# 693        Enterprise  Germany         VTT            High      $552.00
# 694        Government   France         VTT            High      $293.00
# 696    Small Business   Mexico    Amarilla            High      $546.00
#
#      Manufacturing Price   Sale Price    Gross Sales     Discounts   \
# ...

# %%
df[df['Month Number'] == df['Month Number'].max()]
# Out:
#               Segment                   Country     Product   Discount Band   \
# 5          Government                   Germany   Carretera            None
# 15          Midmarket  United States of America     Montana            None
# 28          Midmarket                    Canada       Paseo            None
# 29         Government                    Canada       Paseo            None
# 30         Government                   Germany       Paseo            None
# ..                ...                       ...          ...             ...
# 680  Channel Partners  United States of America       Paseo            High
# 681        Government                    France       Paseo            High
# 686        Enterprise  United States of America        Velo            High
# 687  Channel Partners  United States of America        Velo            High
# 694        Government                    France         VTT            High
#
# ...

# %%
df[['Segment', 'Country']][df['Month Number'] > 6]
# Out:
#             Segment  Country
# 5        Government  Germany
# 11       Enterprise   Canada
# 12   Small Business   Mexico
# 13       Government  Germany
# 14       Enterprise   Canada
# ..              ...      ...
# 691       Midmarket  Germany
# 692      Enterprise   Canada
# 693      Enterprise  Germany
# 694      Government   France
# 696  Small Business   Mexico
#
# [455 rows x 2 columns]

# %%
#Knowing the Index Range
df.index
# Out:
# RangeIndex(start=0, stop=700, step=1)

# %%
#Setting a column as Index
df1 = df.set_index('Segment')
df1
# Out:
#                                    Country     Product   Discount Band   \
# Segment
# Government                          Canada   Carretera            None
# Government                         Germany   Carretera            None
# Midmarket                           France   Carretera            None
# Midmarket                          Germany   Carretera            None
# Midmarket                           Mexico   Carretera            None
# ...                                    ...          ...             ...
# Small Business                      France    Amarilla            High
# Small Business                      Mexico    Amarilla            High
# Government                          Mexico     Montana            High
# Government                          Canada       Paseo            High
# Channel Partners  United States of America         VTT            High
#
#                   Units Sold   Manufacturing Price   Sale Price   \
# Segment
# ...

# %%
df.set_index('Segment', inplace=True)
df
# Out:
#                                    Country     Product   Discount Band   \
# Segment
# Government                          Canada   Carretera            None
# Government                         Germany   Carretera            None
# Midmarket                           France   Carretera            None
# Midmarket                          Germany   Carretera            None
# Midmarket                           Mexico   Carretera            None
# ...                                    ...          ...             ...
# Small Business                      France    Amarilla            High
# Small Business                      Mexico    Amarilla            High
# Government                          Mexico     Montana            High
# Government                          Canada       Paseo            High
# Channel Partners  United States of America         VTT            High
#
#                   Units Sold   Manufacturing Price   Sale Price   \
# Segment
# ...

# %%
df.loc['Government']
# Out:
#                              Country     Product   Discount Band   \
# Segment
# Government                    Canada   Carretera            None
# Government                   Germany   Carretera            None
# Government                   Germany   Carretera            None
# Government                    France     Montana            None
# Government                   Germany     Montana            None
# ...                              ...          ...             ...
# Government                    Canada         VTT            High
# Government  United States of America         VTT            High
# Government                    France         VTT            High
# Government                    Mexico     Montana            High
# Government                    Canada       Paseo            High
#
#             Units Sold   Manufacturing Price   Sale Price    Gross Sales   \
# Segment
# Government   $1,618.50                 $3.00       $20.00     $32,370.00
# ...

# %%
#Resetting the index
df.reset_index(inplace=True)
df
# Out:
#      index           Segment                   Country     Product   \
# 0        0        Government                    Canada   Carretera
# 1        1        Government                   Germany   Carretera
# 2        2         Midmarket                    France   Carretera
# 3        3         Midmarket                   Germany   Carretera
# 4        4         Midmarket                    Mexico   Carretera
# ..     ...               ...                       ...          ...
# 695    695    Small Business                    France    Amarilla
# 696    696    Small Business                    Mexico    Amarilla
# 697    697        Government                    Mexico     Montana
# 698    698        Government                    Canada       Paseo
# 699    699  Channel Partners  United States of America         VTT
#
#      Discount Band   Units Sold   Manufacturing Price   Sale Price   \
# 0             None    $1,618.50                 $3.00       $20.00
# ...

# %%
#Sorting the Data
df = pd.read_csv("C:\\Users\JANHVI TIWARI\Dropbox\My PC (Janhvi)\Downloads\Financial Sample.csv", parse_dates=['Date'])

# %%
print(df)
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
#Sorting in Ascending Order
df1 = df.sort_values('Date')
df1
# Out:
#         Segment                   Country     Product   Discount Band   \
# 202  Government                    Canada        Velo             Low
# 626  Enterprise                    France   Carretera            High
# 336   Midmarket  United States of America       Paseo          Medium
# 179  Government  United States of America        Velo             Low
# 523   Midmarket                    Mexico        Velo            High
# ..          ...                       ...          ...             ...
# 511   Midmarket                    Mexico     Montana            High
# 164  Enterprise                   Germany       Paseo             Low
# 163  Enterprise                    France       Paseo             Low
# 44   Government                    Canada         VTT            None
# 451  Government                    Mexico         VTT          Medium
#
#      Units Sold   Manufacturing Price   Sale Price    Gross Sales   \
# ...

# %%
#Sorting in Descending Order
df1 = df.sort_values('Date', ascending=False)
df1
# Out:
#               Segment                   Country     Product   Discount Band   \
# 681        Government                    France       Paseo            High
# 572        Government                   Germany       Paseo            High
# 154        Enterprise                   Germany     Montana             Low
# 680  Channel Partners  United States of America       Paseo            High
# 52          Midmarket  United States of America    Amarilla            None
# ..                ...                       ...          ...             ...
# 96   Channel Partners  United States of America    Amarilla             Low
# 314        Government                    Mexico   Carretera          Medium
# 205        Government  United States of America         VTT             Low
# 433  Channel Partners                    France         VTT          Medium
# 202        Government                    Canada        Velo             Low
#
# ...

# %%
df1 = df.sort_values(by=['Date', 'Month Number'], ascending=[False, True])
df1
# Out:
#               Segment                   Country     Product   Discount Band   \
# 5          Government                   Germany   Carretera            None
# 15          Midmarket  United States of America     Montana            None
# 29         Government                    Canada       Paseo            None
# 30         Government                   Germany       Paseo            None
# 44         Government                    Canada         VTT            None
# ..                ...                       ...          ...             ...
# 575  Channel Partners                    Canada    Amarilla            High
# 580        Government                   Germany   Carretera            High
# 602         Midmarket                   Germany        Velo            High
# 626        Enterprise                    France   Carretera            High
# 639         Midmarket                    Canada       Paseo            High
#
# ...

# %%
#Handling Missing Data
#fillna() method to replace the Na and NaN values by a specified value
df1 = df.fillna(0)
df1
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
df1 = df.fillna({'Segment' : 'Name Missing', 'Sales' : 0.0, 'Date' : '00-00-00'})
df1
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
#Want to remove thst rows those having Na or NaN values then use dropna() method
df1 = df.dropna()
df1
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...
